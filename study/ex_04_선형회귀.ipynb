# %% [markdown]
# ### 목표 설정
# - 선형 회귀 모델을 사용해보자
# - 성형 회귀 모델의 가중치와 편향을 확인하는 기능을 살펴 보자

# %%
# 필요한 라이브러리 불러오기

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
# 데이터 생성
X = np.arange(2, 11, 2) # X값은 2부터 11까지 2씩 증가하며 들어감
# X는 공부 시간 느낌
y = np.arange(20, 101, 20) # y값은 20부터 101까지 20씩 증가하며 들어감
# y는 시험 성적 느낌

# %%
# 위의 데이터를 이요하여 직선의 형태 확인해 보기
plt.plot(X, y, marker = 'o')

plt.grid()
plt.legend('X')

plt.show()

# %%
from sklearn.linear_model import LinearRegression

# %%
linear_model = LinearRegression()

# %%
# 선형회귀 모델을 사용해 보기

from sklearn.linear_model import LinearRegression

# %%
X_origin = X

# %%
try : 
    linear_model.fit(X_origin, y)
except ValueError as e:
    print("ValueError가 발생.")
    print(f'{e}')
# 주의 !! 현재 X는 1차원 데이터임
# 선형회귀는 2차원 데이터를 받으려고 함.
print(end='\n\n\n')

X = X.reshape(-1, 1) 
X

# .reshape 로 값을 넣을 때. 변경하는 값은 ''를 넣어야 가장 이상적임.
# Out:
# ValueError가 발생.
# Expected 2D array, got 1D array instead:
# array=[ 2  4  6  8 10].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
# array([[ 2],
#        [ 4],
#        [ 6],
#        [ 8],
#        [10]])

# %% [markdown]
# ![image.png](attachment:97b87664-8383-42bf-805a-d0060e9610b1.png)
#
# - 만약 선형회귀에 1차원 데이터를 넣었을 경우 이런 에러가 나온다.
# - using array.reshape(-1, 1) 가이드 -> reshape를 통해 2차원으로 바꿔라.

# %%
linear_model.fit(X, y)
# Out:
# LinearRegression()

# %%
print(linear_model.coef_)
# coef_ 는 가중치 확인하는 코드
# Out:
# [10.]

# %%
print(linear_model.intercept_)
print(int(linear_model.intercept_))
# intercept_ 는 편향을 확인하는 코드
# Out:
# -1.4210854715202004e-14
# 0

# %% [markdown]
# ![image.png](attachment:d1854ccb-4332-42b9-a657-0ac9d3ad23fd.png)
#
# - 즉, y = 10x + 0  라는 식이 나오게 된다.
# - 가중치(w) : 10
# - 편향(b) = 0
#
# - 근데 왜 가중치는 [10.] 인가?? : 데이터 속성이 많아질수록 가중치는 늘어나게 된다. 따라서 배열 구조로 반환된다.
